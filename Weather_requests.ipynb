# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
from darksky import forecast

# %%
#converting time
from darksky import forecast
from datetime import datetime as dt
CHICAGO = api_key,41.964825,-87.6807197

# %%
#get data from 25 December 2016 to 25 November 2018 1469422800 1543125600 855 86400
t_initial = dt(2016, 12, 25).isoformat()
t_final = dt(2018, 11, 25).isoformat()

time_x = 1469422800
Date = []
Temperature = []
Cloud = []
Precipitation = []
Summary = []

for x in range(1,855):  
    chicago = forecast(*CHICAGO, time=time_x)
    Date.append(chicago.time)
    Temperature.append(chicago.temperature)
    #Cloud.append(chicago.cloudCover)
    Precipitation.append(chicago.precipProbability)
    Summary.append(chicago.summary)
    time_x += 86400

Summary
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-6332491a169f> in <module>()
#      11
#      12 for x in range(1,855):
# ---> 13     chicago = forecast(*CHICAGO, time=time_x)
#      14     Date.append(chicago.time)
#      15     Temperature.append(chicago.temperature)
#
# /anaconda3/lib/python3.7/site-packages/darksky/__init__.py in forecast(key, latitude, longitude, time, timeout, **queries)
#       5
#       6 def forecast(key, latitude, longitude, time=None, timeout=None, **queries):
# ----> 7     return Forecast(key, latitude, longitude, time, timeout, **queries)
#
# /anaconda3/lib/python3.7/site-packages/darksky/forecast.py in __init__(self, key, latitude, longitude, time, timeout, **queries)
#      15     def __init__(self, key, latitude, longitude, time=None, timeout=None, **queries):
# ...

# %%
Weather_results = pd.DataFrame(
    {'Date': Date,
     'Temperature': Temperature,
     'Precipitation' : Precipitation,
     'Summary' : Summary
    })

# %%
Weather_results = pd.read_csv('weatherresults.csv')

Formatted_Date = []
import time

for date in Weather_results['Date']:
    f = time.strftime('%Y-%m-%d', time.localtime(date))
    Formatted_Date.append(f)

Weather_results['Formatted_Date'] = Formatted_Date

del Weather_results['Unnamed: 0']

Weather_results
# Out:
#            Date  Temperature  Precipitation        Summary Formatted_Date
# 0    1482645600        34.26           0.00       Overcast     2016-12-25
# 1    1482732000        39.56           0.68        Drizzle     2016-12-26
# 2    1482818400        28.81           0.00          Clear     2016-12-27
# 3    1482904800        23.65           0.00          Clear     2016-12-28
# 4    1482991200        34.61           0.00          Clear     2016-12-29
# 5    1483077600        31.36           0.00       Overcast     2016-12-30
# 6    1483164000        36.83           0.00  Partly Cloudy     2016-12-31
# 7    1483250400        25.25           0.00          Clear     2017-01-01
# 8    1483336800        31.15           0.00          Clear     2017-01-02
# 9    1483423200        39.20           0.13          Foggy     2017-01-03
# 10   1483509600        20.32           0.00          Clear     2017-01-04
# 11   1483596000         8.68           0.00       Overcast     2017-01-05
# ...

# %%
Weather_results.to_csv('weatherresults.csv')
